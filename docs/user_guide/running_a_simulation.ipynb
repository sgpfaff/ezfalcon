# %% [markdown]
# # Running a Simulation
#
# 🚧 *Still working on it...* 🚧

# %% [markdown]
# ## The {meth}`~tambora.simulation.Sim.run` Method
# 🚧 *Still working on it...* 🚧

# %% [markdown]
# ## Running in C
# 🚧 *Still working on it...* 🚧

# %% [markdown]
# ## Caching Options
#
# 🚧 *Still working on it...* 🚧

# %% [markdown]
# ## API
#
# ```{eval-rst}
# .. automethod:: tambora.simulation.Sim.run
#
# ```
