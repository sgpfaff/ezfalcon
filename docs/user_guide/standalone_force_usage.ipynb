# %% [markdown]
# # Usage as Standalone Force Calculator

# %%
from tambora.tools import mkPlummer_galpy
pos, _, mass = mkPlummer_galpy(n=10000, m=1e5, b=10.0)

from tambora.dynamics import FalcONGravity

selfgrav = FalcONGravity(eps=0.01, theta=0.5)

# %%
from tambora.dynamics import ExternalGalpyPotential
from galpy.potential import MWPotential2014
mw = ExternalGalpyPotential(MWPotential2014)

# %%
netforce = selfgrav + mw
