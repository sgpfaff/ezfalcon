# %% [markdown]
# # Self-Gravity Force and Solvers

# %% [markdown]
# ## Supported Self-Gravity Solvers
# 🚧 *Still working on it...* 🚧
#
# ### falcON
# 🚧 *Still working on it...* 🚧
#
# ### Direct Summation
# 🚧 *Still working on it...* 🚧

# %% [markdown]
# ## Self-Gravity Classes as Standalone Solvers
# 🚧 *Still working on it...* 🚧
