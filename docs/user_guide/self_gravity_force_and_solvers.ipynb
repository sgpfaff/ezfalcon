# %% [markdown]
# # Self-Gravity Solvers

# %% [markdown]
# 🚧 *Still working on it...* 🚧
#
# ## falcON ({class}`~tambora.dynamics.forces.self_gravity.SelfGravity.FalcONGravity`)
# 🚧 *Still working on it...* 🚧
#
# ## Direct Summation ({class}`~tambora.dynamics.forces.self_gravity.SelfGravity.DirectSummationGravity`)
# 🚧 *Still working on it...* 🚧

# %% [markdown]
# ## API
# ```{eval-rst}
# .. autoclass:: tambora.dynamics.forces.self_gravity.SelfGravity.DirectSummationGravity
#
# .. autoclass:: tambora.dynamics.forces.self_gravity.SelfGravity.FalcONGravity
#
# .. autoclass:: tambora.dynamics.forces.self_gravity.SelfGravity.NullSelfGravity
# ```
