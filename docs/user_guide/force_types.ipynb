# %% [markdown]
# # Types of Forces

# %% [markdown]
# ## Self-Gravity Forces
# 🚧 *Still working on it...* 🚧
#
# ## Conservative Forces
# 🚧 *Still working on it...* 🚧
#
# ## Non-Conservative Forces
# 🚧 *Still working on it...* 🚧
