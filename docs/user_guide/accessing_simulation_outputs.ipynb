# %% [markdown]
# # Accessing Simulation Results
# 🚧 *Still working on it...* 🚧

# %% [markdown]
# ## Evaluating Forces on Particles
#
# ### Speeding Up With Cached Results
# 🚧 *Still working on it...* 🚧
#
# ### Recomputing Self-Gravity Forces
# 🚧 *Still working on it...* 🚧
#
# ### Evaluating Self-Gravity on an Individual Component
#
# You can choose whether or not to use all particles in the simulation or only those in the same component when computing self-gravity on an individual component.
#
# ### Evaluating External Forces
#
# You can also use the {func}`~tambora.simulation.Sim.compute_external_pot` method to compute the external potential and the
# {func}`~tambora.simulation.Sim.external_acc`, {func}`~tambora.simulation.Sim.external_ax`, {func}`~tambora.simulation.Sim.external_ay`, {func}`~tambora.simulation.Sim.external_az` methods to compute the external acceleration
# from the added potentials at any point in time during the simulation.

# %% [markdown]
# ## Plotting Energy and Momentum Conservation
#
# 🚧 *Still working on it...* 🚧
