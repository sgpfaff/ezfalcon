# %% [markdown]
# `ezfalcon` revolves around the `Sim` object which orchestrates integration, adding and organizing particles, and more. To get you going, we'll first start by exploring how particles are added to and accessed from the `Sim` object.

# %%
from ezfalcon.simulation import Sim
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['font.size'] = 14
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 18 
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['xtick.major.width'] = 1.5
plt.rcParams['ytick.major.width'] = 1.5
plt.rcParams['ytick.right'] = True
plt.rcParams['xtick.top'] = True
plt.rcParams['mathtext.fontset'] = 'stix'
# plt.rcParams['font.family'] = 'serif'
# plt.rcParams['font.serif'] = 'Times New Roman'
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['ytick.minor.visible'] = True

# %% [markdown]
# The first thing to do is make an instance of the object:

# %%
sim = Sim()

# %% [markdown]
# # Adding Particles

# %% [markdown]
# We can use the `.add_particles` method to add particles to the simulation.

# %%
# random particle data:
pos1 = np.random.rand(1000, 3) * 20  - 10 # positions in kpc
vel1 = np.random.rand(1000, 3) * 200  # velocities in
mass1 = np.ones(1000) * 1e5  # masses in Msun

# adding to sim
sim.add_particles('component1', pos1, vel1, mass1)

# %% [markdown]
# From this point on, accessing the properties of the particles is easy with the many methods of the `Sim` class.

# %%
sim.x(0)[:10]
# Out:
# array([ 4.00173594, -6.26814395, -5.09320898, -2.13403596, -3.21418994,
#         5.52537928, -0.96626341, -1.79525884,  4.3594536 ,  7.38507498])

# %%
sim.vx(0)[:10]
# Out:
# array([121.95708726, 150.8119848 ,  73.92152514,   3.65859268,
#        176.32847424, 145.97311094,  12.61575538,  33.97109448,
#        179.20745397, 181.86031861])

# %% [markdown]
# # Multiple Components
#
# Working with multiple components is very similar and just as easy!

# %%
pos2 = np.random.rand(1000, 3) * 2  - 1 # positions in kpc
vel2 = np.random.rand(1000, 3) * 20  # velocities in
mass2 = np.ones(1000) * 1e5  # masses in Msun

# %%
sim.add_particles('component2', pos2, vel2, mass2)

# %% [markdown]
# To get info about the particles in a specific component, you just do `sim.component_name` followed by whatever method you are interested in.

# %%
sim.component2.pos(0)[:,:10]
# Out:
# array([[-0.22321198,  0.49947126, -0.11549747],
#        [ 0.34774586,  0.6238167 ,  0.44648217],
#        [ 0.14014793, -0.2779922 , -0.1925442 ],
#        ...,
#        [-0.23317942,  0.39322932, -0.36385431],
#        [-0.42707896, -0.10184319, -0.09894531],
#        [ 0.91885442, -0.81407009,  0.36765986]], shape=(1000, 3))

# %%
sim.component1.x(0)[:10]
# Out:
# array([ 4.00173594, -6.26814395, -5.09320898, -2.13403596, -3.21418994,
#         5.52537928, -0.96626341, -1.79525884,  4.3594536 ,  7.38507498])

# %%
plt.scatter(sim.component1.x(), sim.component1.y(), s=1, label='Component 1')
plt.scatter(sim.component2.x(), sim.component2.y(), s=1, label='Component 2')
plt.xlabel('x [kpc]')
plt.ylabel('y [kpc]')
plt.legend(markerscale=5)

# %% [markdown]
# **Other features**
#
# * particle tagging
