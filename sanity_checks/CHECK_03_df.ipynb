# %%
from galpy.df import isotropicPlummerdf, kingdf
from galpy.potential import PlummerPotential

import numpy as np
import astropy.units as u
import matplotlib.pyplot as plt

plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['font.size'] = 14
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 18 
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['xtick.major.width'] = 1.5
plt.rcParams['ytick.major.width'] = 1.5
plt.rcParams['ytick.right'] = True
plt.rcParams['xtick.top'] = True
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Times New Roman'
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['ytick.minor.visible'] = True

# %%
pp = PlummerPotential(amp=1e10 * u.Msun, b=1.0 * u.kpc)
pdf = isotropicPlummerdf(pot=pp)

# %%
king = kingdf(W0=5, M=1e10*u.Msun)

# %%
o_king = king.sample(n=1000)

# %%
plt.scatter(o_king.x(), o_king.y(), s=1)

# %%
from ezfalcon.util import galpydfsampler

# %%
galpydfsampler(df=king, n=1000, m_total=1e10*u.Msun)
# Out:
# (array([[ 0.23822531, -0.0741428 ,  0.28709894],
#         [ 0.20040252,  0.34744556,  0.75859235],
#         [ 2.03457865, -0.39877179,  0.00398168],
#         ...,
#         [-0.21202559, -0.04575975,  1.20727437],
#         [ 0.24886156,  0.07551769, -0.38054353],
#         [ 3.41343841, -1.25556646,  0.34695275]], shape=(1000, 3)),
#  array([[-0.05369089,  0.07400855,  0.01804102],
#         [-0.01529038, -0.0467531 ,  0.05250738],
#         [-0.02695028,  0.01234128,  0.04171634],
#         ...,
#         [-0.03155416, -0.10818794, -0.04479654],
#         [-0.06637762, -0.05477356, -0.10243456],
#         [-0.06213919,  0.05473776, -0.04381858]], shape=(1000, 3)),
#  <Quantity [10000000., 10000000., 10000000., 10000000., 10000000.,
#             10000000., 10000000., 10000000., 10000000., 10000000.,
#             10000000., 10000000., 10000000., 10000000., 10000000.,
#             10000000., 10000000., 10000000., 10000000., 10000000.,
# ...
