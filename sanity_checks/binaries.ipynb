# %%
from ezfalconv2.simulation import Sim
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/gabrielpfaffman/Repos/ezfalconv2/ezfalconv2/simulation/simulation.py:361: SyntaxWarning: invalid escape sequence '\D'
#   plt.ylabel("$|\Delta E / E_0|$")

# %%
from galpy import potential
SUPPORTED_GALPY_SPHERICAL_POTENTIALS = [
    potential.BurkertPotential(),
    potential.TwoPowerSphericalPotential(),
    potential.DehnenCoreSphericalPotential(),
    potential.DehnenSphericalPotential(),
    potential.EinastoPotential(),
    potential.HernquistPotential(),
    potential.interpSphericalPotential(rforce=lambda r: -1./r,
                        rgrid=np.geomspace(0.01,20,101),Phi0=0.),
    potential.IsochronePotential(),
    potential.JaffePotential(),
    potential.KeplerPotential(),
    potential.KingPotential(),
    potential.NFWPotential(),
    potential.PlummerPotential(),
    potential.PowerSphericalPotential(),
    potential.PowerSphericalPotentialwCutoff(),
    potential.PseudoIsothermalPotential(),
]

# %%
ALL_POTENTIALS = SUPPORTED_GALPY_SPHERICAL_POTENTIALS + [
    potential.MiyamotoNagaiPotential(),
]

# %%
SUPPORTED_GALPY_SPHERICAL_POTENTIALS
# Out:
# [BurkertPotential with internal parameters: amp=1.0, a=2.0 and physical outputs off,
#  TwoPowerSphericalPotential with internal parameters: amp=1.0, a=5.0, alpha=1.5, beta=3.5 and physical outputs off,
#  DehnenCoreSphericalPotential with internal parameters: amp=1.0, a=1.0 and physical outputs off,
#  DehnenSphericalPotential with internal parameters: amp=1.0, a=1.0, alpha=1.5 and physical outputs off,
#  EinastoPotential with internal parameters: amp=1.0, h=2.0, n=1 and physical outputs off,
#  HernquistPotential with internal parameters: amp=1.0, a=1.0 and physical outputs off,
#  interpSphericalPotential with internal parameters: rgrid=[1.00000000e-02 1.07897231e-02 1.16418125e-02 1.25611933e-02
#   1.35531798e-02 1.46235057e-02 1.57783578e-02 1.70244112e-02
#   1.83688683e-02 1.98195003e-02 2.13846920e-02 2.30734906e-02
#   2.48956574e-02 2.68617250e-02 2.89830576e-02 3.12719166e-02
#   3.37415321e-02 3.64061789e-02 3.92812590e-02 4.23833909e-02
#   4.57305052e-02 4.93419489e-02 5.32385966e-02 5.74429717e-02
#   6.19793759e-02 6.68740305e-02 7.21552273e-02 7.78534923e-02
#   8.40017626e-02 9.06355759e-02 9.77932769e-02 1.05516238e-01
#   1.13849099e-01 1.22840026e-01 1.32540986e-01 1.43008054e-01
#   1.54301731e-01 1.66487295e-01 1.79635182e-01 1.93821388e-01
#   2.09127911e-01 2.25643225e-01 2.43462792e-01 2.62689611e-01
#   2.83434817e-01 3.05818320e-01 3.29969499e-01 3.56027954e-01
#   3.84144304e-01 4.14481068e-01 4.47213595e-01 4.82531087e-01
#   5.20637682e-01 5.61753643e-01 6.06116627e-01 6.53983058e-01
#   7.05629612e-01 7.61354813e-01 8.21480762e-01 8.86354997e-01
#   9.56352500e-01 1.03187787e+00 1.11336765e+00 1.20129286e+00
#   1.29616174e+00 1.39852263e+00 1.50896719e+00 1.62813382e+00
#   1.75671131e+00 1.89544286e+00 2.04513037e+00 2.20663904e+00
#   2.38090242e+00 2.56892779e+00 2.77180196e+00 2.99069756e+00
#   3.22687986e+00 3.48171402e+00 3.75667303e+00 4.05334618e+00
#   4.37344830e+00 4.71882962e+00 5.09148650e+00 5.49357296e+00
#   5.92741311e+00 6.39551462e+00 6.90058320e+00 7.44553820e+00
#   8.03352956e+00 8.66795596e+00 9.35248448e+00 1.00910718e+01
#   1.08879871e+01 1.17478366e+01 1.26755904e+01 1.36766110e+01
#   1.47566846e+01 1.59220541e+01 1.71794555e+01 1.85361568e+01
#   2.00000000e+01], Phi0=0.0 and physical outputs off,
#  IsochronePotential with internal parameters: amp=1.0, b=1.0 and physical outputs off,
#  JaffePotential with internal parameters: amp=1.0, a=1.0 and physical outputs off,
#  KeplerPotential with internal parameters: amp=1.0 and physical outputs off,
#  KingPotential with physical outputs off,
#  NFWPotential with internal parameters: amp=1.0, a=1.0 and physical outputs off,
#  PlummerPotential with internal parameters: amp=1.0, b=0.8 and physical outputs off,
#  PowerSphericalPotential with internal parameters: amp=6.283185307179586, alpha=1.0 and physical outputs off,
#  PowerSphericalPotentialwCutoff with internal parameters: amp=1.0, alpha=1.0, rc=1.0 and physical outputs off,
#  PseudoIsothermalPotential with internal parameters: amp=1.0, a=1.0 and physical outputs off]
