# %%
from ezfalcon.dynamics.integration import _integrate
from galpy.util.coords import cyl_to_rect, cyl_to_rect_vec
from ezfalcon.util import _galpy_pot_to_acc_fn, _galpy_pot_to_pot_fn
from ezfalcon.simulation import Sim
from galpy.potential import NFWPotential
from galpy.orbit import Orbit
import astropy.units as u
import numpy as np


t_end = 80 * u.Myr # INCREASE TO 100 Myr FOR REAL TESTS
dt = 1/200*u.Myr
ts = np.arange(0, t_end.value + dt.value, dt.value) * u.Myr
pot = NFWPotential(amp=1e13*u.Msun, a=20*u.kpc)
R, vR, vT, z, vz, phi = 8., 0.1, 220.0, 0., 0.5, 0.
pot.turn_physical_on()
pos = np.array([cyl_to_rect(R, phi, z)])
vel = np.array([(cyl_to_rect_vec(vR, vT, vz, phi) * u.km/u.s).to(u.kpc/u.Myr).value])
acc_fn = _galpy_pot_to_acc_fn(pot)
pos_out, vel_out, ts_out = _integrate(pos, vel, np.array([1.]), False, None, [acc_fn], 
                                      t_end.value, dt.value, dt.value, eps=0.0,
                                      return_self_potential=False, return_self_acceleration=False)

pot_fn = _galpy_pot_to_pot_fn(pot)
nsnaps, npart = vel_out.shape[:2]
KE = 0.5 * np.sum(vel_out**2, axis=-1)  # (nsnaps, N)
PE = pot_fn(pos_out.reshape(-1, 3), t=0).reshape(nsnaps, npart)  # flatten → eval → reshape
E_out = ((KE + PE).squeeze()* u.kpc**2/u.Myr**2).to(u.km**2/u.s**2).value
Lz_out = (pos_out[...,0]*vel_out[...,1] - pos_out[...,1]*vel_out[...,0]).squeeze()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from ezfalcon.dynamics.integration import _integrate
#       2 from galpy.util.coords import cyl_to_rect, cyl_to_rect_vec
#       3 from ezfalcon.util import _galpy_pot_to_acc_fn, _galpy_pot_to_pot_fn
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/dynamics/__init__.py:1
# ----> 1 from .acceleration import *
#       2 from .integration import _integrate
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/dynamics/acceleration/__init__.py:1
# ----> 1 from .self_gravity import self_gravity
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/dynamics/acceleration/self_gravity.py:5
#       1 '''
#       2 Accelerations from self-gravity with pyfalcon.
#       3 '''
#       4 import pyfalcon
# ----> 5 from ...util import G_INTERNAL
#       6 import numpy as np
#       8 def self_gravity(pos, mass, method='falcON', return_potential=True, **kwargs):
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/util/__init__.py:3
#       1 from .units import *
#       2 from .coords import cyl2cart
# ----> 3 from ._galpy_bridge import _galpy_pot_to_acc_fn, _galpy_pot_to_pot_fn
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/util/_galpy_bridge.py:6
#       4 from galpy.util.coords import rect_to_cyl, cyl_to_rect, cyl_to_rect_vec
#       5 from galpy.util.conversion import get_physical
# ----> 6 from galpy import potential
#       7 from .units import KMS_TO_KPCMYR, GYR_TO_MYR
#       8 import numpy as np
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/lib/python3.12/site-packages/galpy/potential/__init__.py:1
# ----> 1 from . import (
#       2     AdiabaticContractionWrapperPotential,
#       3     AnyAxisymmetricRazorThinDiskPotential,
#       4     AnySphericalPotential,
#       5     BurkertPotential,
#       6     ChandrasekharDynamicalFrictionForce,
#       7     CompositePotential,
#       8     CorotatingRotationWrapperPotential,
#       9     CosmphiDiskPotential,
#      10     CylindricallySeparablePotentialWrapper,
#      11     DehnenBarPotential,
#      12     DehnenSmoothWrapperPotential,
#      13     DiskSCFPotential,
#      14     DoubleExponentialDiskPotential,
#      15     EinastoPotential,
#      16     EllipticalDiskPotential,
#      17     FDMDynamicalFrictionForce,
#      18     FerrersPotential,
#      19     FlattenedPowerPotential,
#      20     Force,
#      21     GaussianAmplitudeWrapperPotential,
#      22     HenonHeilesPotential,
#      23     HomogeneousSpherePotential,
#      24     IsochronePotential,
#      25     IsothermalDiskPotential,
#      26     KGPotential,
#      27     KingPotential,
#      28     KuzminDiskPotential,
#      29     KuzminKutuzovStaeckelPotential,
#      30     KuzminLikeWrapperPotential,
#      31     LogarithmicHaloPotential,
#      32     MiyamotoNagaiPotential,
#      33     MN3ExponentialDiskPotential,
#      34     MovingObjectPotential,
#      35     NonInertialFrameForce,
#      36     NullPotential,
#      37     NumericalPotentialDerivativesMixin,
#      38     OblateStaeckelWrapperPotential,
#      39     PerfectEllipsoidPotential,
#      40     PlummerPotential,
#      41     Potential,
#      42     PowerSphericalPotential,
#      43     PowerSphericalPotentialwCutoff,
#      44     PowerTriaxialPotential,
#      45     PseudoIsothermalPotential,
#      46     RazorThinExponentialDiskPotential,
#      47     RingPotential,
#      48     RotateAndTiltWrapperPotential,
#      49     SCFPotential,
#      50     SnapshotRZPotential,
#      51     SoftenedNeedleBarPotential,
#      52     SolidBodyRotationWrapperPotential,
#      53     SphericalShellPotential,
#      54     SpiralArmsPotential,
#      55     SteadyLogSpiralPotential,
#      56     TimeDependentAmplitudeWrapperPotential,
#      57     TransientLogSpiralPotential,
#      58     TriaxialGaussianPotential,
#      59     TwoPowerSphericalPotential,
#      60     TwoPowerTriaxialPotential,
#      61     interpRZPotential,
#      62     interpSphericalPotential,
#      63     linearCompositePotential,
#      64     linearPotential,
#      65     planarCompositePotential,
#      66     planarForce,
#      67     planarPotential,
#      68     verticalPotential,
#      69 )
#      71 #
#      72 # Functions
#      73 #
#      74 evaluatePotentials = Potential.evaluatePotentials
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/lib/python3.12/site-packages/galpy/potential/SnapshotRZPotential.py:9
#       6 from scipy import interpolate
#       8 from ..util._optional_deps import _PYNBODY_GE_20, _PYNBODY_LOADED
# ----> 9 from .interpRZPotential import (
#      10     calc_2dsplinecoeffs_c,
#      11     interpRZPotential,
#      12     scalarVectorDecorator,
#      13     zsymDecorator,
#      14 )
#      15 from .Potential import Potential
#      17 if _PYNBODY_LOADED:
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/lib/python3.12/site-packages/galpy/potential/interpRZPotential.py:16
#      12 from .Potential import Potential
#      14 _DEBUG = False
# ---> 16 _lib, ext_loaded = _load_extension_libs.load_libgalpy()
#      19 def scalarVectorDecorator(func):
#      20     """Decorator to return scalar outputs as a set"""
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/lib/python3.12/site-packages/galpy/util/_load_extension_libs.py:70, in load_libgalpy(check_openmp_issue)
#      68     return (_libgalpy, _libgalpy_loaded)
#      69 if check_openmp_issue and not _checked_openmp_issue:
# ---> 70     if _detect_openmp_issue():  # pragma: no cover
#      71         _libgalpy_loaded = False
#      72         return (_libgalpy, _libgalpy_loaded)
#
# File /geir_data/scr/gabrielspace/ezfalcon/ezfalcon/lib/python3.12/site-packages/galpy/util/_load_extension_libs.py:33, in _detect_openmp_issue()
#      27 def _detect_openmp_issue():
#      28     # Check whether we get an error of the type "OMP: Error #15: Initializing libomp.dylib, but found libomp.dylib already initialized.", which occurs, e.g., when using pip-installed galpy with conda-installed numpy and causes segmentation faults and general issues
#      29     # This is a known issue with OpenMP and is not galpy's fault (GitHub Copilot suggested this comment!)
#      30
#      31     # Check this by running a subprocess that tries to import the C library without this check
#      32     try:
# ---> 33         subprocess.run(
#      34             [
#      35                 sys.executable,
#      36                 "-c",
#      37                 "from galpy.util._load_extension_libs import load_libgalpy; load_libgalpy(check_openmp_issue=False)",
#      38             ],
#      39             check=True,
#      40             capture_output=True,
#      41         )
#      42     except subprocess.CalledProcessError as e:  # pragma: no cover
#      43         if re.match(
#      44             r"OMP: Error #15: Initializing libomp[0-9]*.dylib, but found libomp[0-9]*.dylib already initialized",
#      45             e.stderr.decode("utf-8"),
#      46         ):
#
# File /geir_data/scr/gabrielspace/miniforge3/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /geir_data/scr/gabrielspace/miniforge3/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /geir_data/scr/gabrielspace/miniforge3/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /geir_data/scr/gabrielspace/miniforge3/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
o_galpy = Orbit([R*u.kpc, vR*u.km/u.s, vT*u.km/u.s, z*u.kpc, vz*u.km/u.s, phi*u.rad])
o_galpy.integrate(ts, pot, method='leapfrog_c', dt=dt)
o_galpy.turn_physical_on()

# %%
import matplotlib.pyplot as plt
plt.plot(ts, np.abs((o_galpy.E(ts) - o_galpy.E(ts)[0]) / o_galpy.E(ts)[0]), label='galpy', ls='-')
plt.plot(ts, np.abs((E_out - E_out[0]) / E_out[0]), label='ezfalcon', ls='--')
plt.yscale('log')
plt.xlabel('Time [Myr]')
plt.ylabel('Relative Energy Error')
plt.legend()
